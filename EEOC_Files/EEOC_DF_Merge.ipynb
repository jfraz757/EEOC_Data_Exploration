# %% [markdown]
# I am creating a function to stack all of my EEOC1 2023-2014 Dataframes into one large table.

# %%
import pandas as pd
from pathlib import Path
import os

# %%
def stack_csv(file_folder):
    folder_path = Path(file_folder)

    df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]

    final_df = pd.concat(df_list, ignore_index=True)
    
    EEOC1_Master_Stacked = final_df

    EEOC1_Master_Stacked.to_csv(r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv', index=False)

    return EEOC1_Master_Stacked

my_folder = r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data'

final_stack = stack_csv(my_folder)
print(final_stack.head())
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Male_Total, 6: Female_Total, 7: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Hisp_Total, 6: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Male_Total, 6: Female_Total, 7: TOTAL1_2, 8: WHM10, 9: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Hisp_Total, 6: Male_Total, 7: Female_Total, 8: TOTAL1_2, 9: WHM10, 10: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Hisp_Total, 6: Male_Total, 7: Female_Total, 8: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Hisp_Total, 6: Clericals, 7: TOTAL1_2, 8: WHM10, 9: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  tomrT1  tomrT2 tomrT3 tomrT4  \
# 0                                NaN  ...     NaN     NaN    NaN    NaN
# 1                                NaN  ...     NaN     NaN    NaN    NaN
# 2                    Crop Production  ...     NaN     NaN    NaN    NaN
# 3  Animal Production and Aquaculture  ...     NaN     NaN    NaN    NaN
# 4               Forestry and Logging  ...     NaN     NaN    NaN    NaN
#
#   tomrT5 tomrT6 tomrT7 tomrT8 tomrT9 tomrT1_2
# 0    NaN    NaN    NaN    NaN    NaN      NaN
# 1    NaN    NaN    NaN    NaN    NaN      NaN
# 2    NaN    NaN    NaN    NaN    NaN      NaN
# 3    NaN    NaN    NaN    NaN    NaN      NaN
# 4    NaN    NaN    NaN    NaN    NaN      NaN
#
# [5 rows x 297 columns]

# %%
df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv')
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_87896\2880195732.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Hisp_Total, 6: NHOPIT10, 7: Male_Total, 8: Female_Total, 9: TOTAL1_2, 10: WHM10, 11: WHF10, 12: NHOPIT1, 13: NHOPIT2, 14: NHOPIT3, 15: NHOPIT4, 16: NHOPIT5, 17: NHOPIT6, 18: NHOPIT7, 19: NHOPIT8, 20: NHOPIT9, 21: NHOPIT1_2, 22: TOMRT1, 23: TOMRT2, 24: TOMRT3, 25: TOMRT4, 26: TOMRT5, 27: TOMRT6, 28: TOMRT7, 29: TOMRT8, 30: TOMRT9, 31: TOMRT1_2, 32: nhopiT10, 33: nhopiT1, 34: nhopiT2, 35: nhopiT3, 36: nhopiT4, 37: nhopiT5, 38: nhopiT6, 39: nhopiT7, 40: nhopiT8, 41: nhopiT9, 42: nhopiT1_2, 43: tomrT1, 44: tomrT2, 45: tomrT3, 46: tomrT4, 47: tomrT5, 48: tomrT6, 49: tomrT7, 50: tomrT8, 51: tomrT9, 52: tomrT1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv')

# %%
df.head()
# Out:
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  tomrT1  tomrT2 tomrT3 tomrT4  \
# 0                                NaN  ...     NaN     NaN    NaN    NaN
# 1                                NaN  ...     NaN     NaN    NaN    NaN
# 2                    Crop Production  ...     NaN     NaN    NaN    NaN
# 3  Animal Production and Aquaculture  ...     NaN     NaN    NaN    NaN
# 4               Forestry and Logging  ...     NaN     NaN    NaN    NaN
#
#   tomrT5 tomrT6 tomrT7 tomrT8 tomrT9 tomrT1_2
# 0    NaN    NaN    NaN    NaN    NaN      NaN
# 1    NaN    NaN    NaN    NaN    NaN      NaN
# 2    NaN    NaN    NaN    NaN    NaN      NaN
# 3    NaN    NaN    NaN    NaN    NaN      NaN
# 4    NaN    NaN    NaN    NaN    NaN      NaN
#
# [5 rows x 297 columns]

# %%
df['Year'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
df['Year'].value_counts()
# Out:
# Year
# 2023    105613
# 2022    103475
# 2021     45143
# 2016     44460
# 2019     44332
# 2015     44179
# 2018     43919
# 2017     43728
# 2014     43707
# 2020     42815
# Name: count, dtype: int64
