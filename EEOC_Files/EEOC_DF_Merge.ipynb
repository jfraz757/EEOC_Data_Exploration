# %% [markdown]
# I am creating a function to stack all of my EEOC1 2023-2014 Dataframes into one large table.

# %%
import pandas as pd
from pathlib import Path
import os

# %%
def stack_csv(file_folder):
    folder_path = Path(file_folder)

    df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]

    final_df = pd.concat(df_list, ignore_index=True)
    
    EEOC1_Master = final_df

    EEOC1_Master.to_csv(r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_Master.csv', index=False)

    return EEOC1_Master

my_folder = r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data'

final_stack = stack_csv(my_folder)
print(final_stack.head())
# Out:
#    Year State County                                 NAICS2_Name  Male_Total  \
# 0  2014   NaN    NaN                                         NaN  26728926.0
# 1  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting    187857.0
# 2  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting     90891.0
# 3  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting     45938.0
# 4  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting      2497.0
#
#    Female_Total  White_Total  Black_Total  Hisp_Total  Asian_Total  ...  \
# 0    24422889.0   32348361.0    7408929.0   7066158.0    3068313.0  ...
# 1       90345.0      86127.0      15875.0    165020.0       7013.0  ...
# 2       43864.0      30544.0       3682.0     95595.0       3067.0  ...
# 3       22085.0      32517.0       9389.0     22823.0       2142.0  ...
# 4         734.0       2650.0        132.0       305.0         54.0  ...
#
#    Multi_Race_Total  Senior_Managers  Professionals  Technicians  \
# ...

# %%
df = pd.read_csv(r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_Master.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 561371 entries, 0 to 561370
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Year              561371 non-null  int64
#  1   State             519315 non-null  str
#  2   County            301101 non-null  str
#  3   NAICS2_Name       525862 non-null  str
#  4   Male_Total        554866 non-null  float64
#  5   Female_Total      554866 non-null  float64
#  6   White_Total       555259 non-null  float64
#  7   Black_Total       488902 non-null  float64
#  8   Hisp_Total        500569 non-null  float64
#  9   Asian_Total       382013 non-null  float64
#  10  Amer_Ind_Total    232288 non-null  float64
#  11  P_Isld_Total      103473 non-null  float64
#  12  Multi_Race_Total  432651 non-null  float64
#  13  Senior_Managers   330195 non-null  float64
#  14  Professionals     472421 non-null  float64
#  15  Technicians       390418 non-null  float64
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 561366    False
# 561367    False
# 561368    False
# 561369    False
# 561370    False
# Length: 561371, dtype: bool

# %%
df.dtypes
# Out:
# Year                  int64
# State                   str
# County                  str
# NAICS2_Name             str
# Male_Total          float64
# Female_Total        float64
# White_Total         float64
# Black_Total         float64
# Hisp_Total          float64
# Asian_Total         float64
# Amer_Ind_Total      float64
# P_Isld_Total        float64
# Multi_Race_Total    float64
# Senior_Managers     float64
# Professionals       float64
# Technicians         float64
# Sales_Workers       float64
# Clericals           float64
# Craft               float64
# Operatives          float64
# Labors              float64
# Mid_Managers        float64
# dtype: object

# %%
df.describe()
# Out:
#                 Year    Male_Total  Female_Total   White_Total   Black_Total  \
# count  561371.000000  5.548660e+05  5.548660e+05  5.552590e+05  4.889020e+05
# mean     2019.366909  9.277693e+03  8.756443e+03  1.053217e+04  3.112389e+03
# std         3.039839  1.659400e+05  1.612690e+05  1.885453e+05  5.600636e+04
# min      2014.000000  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00
# 25%      2017.000000  2.050000e+02  1.530000e+02  2.760000e+02  3.000000e+01
# 50%      2020.000000  6.340000e+02  4.880000e+02  7.810000e+02  1.330000e+02
# 75%      2022.000000  2.302000e+03  1.880000e+03  2.697000e+03  6.390000e+02
# max      2023.000000  3.967136e+07  3.817373e+07  4.274132e+07  1.198683e+07
#
#          Hisp_Total   Asian_Total  Amer_Ind_Total   P_Isld_Total  \
# count  5.005690e+05  3.820130e+05   232288.000000  103473.000000
# mean   3.214948e+03  1.796988e+03      233.047510     225.497946
# std    5.837003e+04  2.884075e+04     2973.876507    2169.969160
# ...

# %%
df.value_counts()
# Out:
# Year  State          County     NAICS2_Name                                       Male_Total  Female_Total  White_Total  Black_Total  Hisp_Total  Asian_Total  Amer_Ind_Total  P_Isld_Total  Multi_Race_Total  Senior_Managers  Professionals  Technicians  Sales_Workers  Clericals  Craft  Operatives  Labors  Mid_Managers
# 2014  Massachusetts  Middlesex  Professional, Scientific, and Technical Services  43900.0     26178.0       54375.0      2422.0       2377.0      9940.0       124.0           66.0          732.0             2792.0           40037.0        2845.0       4979.0         4753.0     144.0  368.0       290.0   233.0           2
#                      Norfolk    Professional, Scientific, and Technical Services  4467.0      2754.0        5605.0       353.0        186.0       1011.0       6.0             6.0           50.0              256.0            3832.0         411.0        391.0          798.0      6.0    4.0         10.0    76.0            2
# ...

# %%
df['Year'].value_counts()
# Out:
# Year
# 2023    105613
# 2022    103475
# 2021     45143
# 2016     44460
# 2019     44332
# 2015     44179
# 2018     43919
# 2017     43728
# 2014     43707
# 2020     42815
# Name: count, dtype: int64

# %%
df["Male_Total"].value_counts()
# Out:
# Male_Total
# 10.0       1192
# 13.0       1152
# 11.0       1151
# 8.0        1122
# 14.0       1104
#            ...
# 23927.0       1
# 73785.0       1
# 84153.0       1
# 35174.0       1
# 60031.0       1
# Name: count, Length: 41942, dtype: int64

# %%
df.Male_Total
# Out:
# 0         26728926.0
# 1           187857.0
# 2            90891.0
# 3            45938.0
# 4             2497.0
#              ...
# 561366         869.0
# 561367         301.0
# 561368         873.0
# 561369         226.0
# 561370          12.0
# Name: Male_Total, Length: 561371, dtype: float64

# %%
df.head()
# Out:
#    Year State County                                 NAICS2_Name  Male_Total  \
# 0  2014   NaN    NaN                                         NaN  26728926.0
# 1  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting    187857.0
# 2  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting     90891.0
# 3  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting     45938.0
# 4  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting      2497.0
#
#    Female_Total  White_Total  Black_Total  Hisp_Total  Asian_Total  ...  \
# 0    24422889.0   32348361.0    7408929.0   7066158.0    3068313.0  ...
# 1       90345.0      86127.0      15875.0    165020.0       7013.0  ...
# 2       43864.0      30544.0       3682.0     95595.0       3067.0  ...
# 3       22085.0      32517.0       9389.0     22823.0       2142.0  ...
# 4         734.0       2650.0        132.0       305.0         54.0  ...
#
#    Multi_Race_Total  Senior_Managers  Professionals  Technicians  \
# ...

# %%
filtered_df = df[(df['Black_Total'] >0 ) & (df['Year'] == '2023')]
filtered_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              0 non-null      int64
#  1   State             0 non-null      str
#  2   County            0 non-null      str
#  3   NAICS2_Name       0 non-null      str
#  4   Male_Total        0 non-null      float64
#  5   Female_Total      0 non-null      float64
#  6   White_Total       0 non-null      float64
#  7   Black_Total       0 non-null      float64
#  8   Hisp_Total        0 non-null      float64
#  9   Asian_Total       0 non-null      float64
#  10  Amer_Ind_Total    0 non-null      float64
#  11  P_Isld_Total      0 non-null      float64
#  12  Multi_Race_Total  0 non-null      float64
#  13  Senior_Managers   0 non-null      float64
#  14  Professionals     0 non-null      float64
#  15  Technicians       0 non-null      float64
# ...
