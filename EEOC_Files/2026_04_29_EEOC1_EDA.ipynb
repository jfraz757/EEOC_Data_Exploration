# %% [markdown]
# Exploratory Data Analysis with my Fresh (4/29/26) EEOC1 Tables

# %%
import pandas as pd
import dtale
import numpy as np
import os

# %%
nat_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_National_Baselines.csv')
state_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_State_Totals.csv')
county_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_County_Totals.csv')
cbsa_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_CBSA_Total.csv')
demogr_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_Demographic_Totals.csv')
master_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\'EEOC_Cleaned_Master_Stacked.csv')
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_19464\3722357634.py:1: DtypeWarning: Columns (0: REGION, 1: DIVISION, 2: CBSA) have mixed types. Specify dtype option on import or set low_memory=False.
#   nat_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_National_Baselines.csv')
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_19464\3722357634.py:6: DtypeWarning: Columns (0: REGION, 1: DIVISION, 2: STATE, 3: COUNTY) have mixed types. Specify dtype option on import or set low_memory=False.
#   master_raw = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\'EEOC_Cleaned_Master_Stacked.csv')

# %%
nat_df = nat_raw.copy()
state_df = state_raw.copy()
county_df = county_raw.copy()
cbsa_df = cbsa_raw.copy()
demogr_df = demogr_raw.copy()
master_df = master_raw.copy()

# %%
#Quick check on some missing variables
df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2023.csv')
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_19464\3243558233.py:2: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2023.csv')

# %%
d = dtale.show(df)
d.open_browser()
df.head()
# Out:
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  AIANM1_2  NHOPIM1_2 TOMRM1_2  \
# 0                                NaN  ...     18884      18537    94570
# 1                                NaN  ...       119         42      217
# ...

# %%
d = dtale.show(demogr_df)
d.open_browser()

# %%
df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data\EEOC1_2014_Cleaned.csv')
d = dtale.show(df)
d.open_browser()
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_19464\2953863340.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data\EEOC1_2014_Cleaned.csv')

# %%
df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Cleaned_Master\EEOC1_Demographic_Totals.csv')
d = dtale.show(df)
d.open_browser()
# Out:
# c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dtale\utils.py:868: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data = data.reset_index(drop=drop_index)
