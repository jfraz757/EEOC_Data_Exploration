# %% [markdown]
# After using my auto cleaning script on EEOC1_2022 I was surpised to see that the Dataframe is signifcantly smaller than EEOC1_2023. Here I am opening both the original and cleaned versions of EEOC_2022 to see what went wrong.

# %%
import pandas as pd

# %%
df_org = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2022.csv')
df_cln = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data\EEOC1_2022_Cleaned.csv')
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_68736\94692994.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_org = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2022.csv')

# %%
df_org.head()
# Out:
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  AIANM1_2  NHOPIM1_2 TOMRM1_2  \
# 0                                NaN  ...     18369      19879    88770
# 1                                NaN  ...       120         47      175
# ...

# %%
df_org_excel = pd.read_excel(r'c:\Users\jfraz\Downloads\EEO1 2022 PUF.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_org_excel = pd.read_excel(r'c:\Users\jfraz\Downloads\EEO1 2022 PUF.xlsx')
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_base.py:494, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#     493 try:
# --> 494     data = io.parse(
#     495         sheet_name=sheet_name,
#     496         header=header,
# ...

# %%
df_org_excel.head()
# Out:
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  AIANM1_2  NHOPIM1_2 TOMRM1_2  \
# 0                                NaN  ...     18369      19879    88770
# 1                                NaN  ...       120         47      175
# ...

# %%
df2023 = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data\EEOC1_2023_Cleaned.csv')
df2023.head()
# Out:
#    Year State County                                 NAICS2_Name  Male_Total  \
# 0  2023   NaN    NaN                                         NaN  39671364.0
# 1  2023   NaN    NaN  Agriculture, Forestry, Fishing and Hunting    270931.0
# 2  2023   NaN    NaN  Agriculture, Forestry, Fishing and Hunting    108316.0
# 3  2023   NaN    NaN  Agriculture, Forestry, Fishing and Hunting     72318.0
# 4  2023   NaN    NaN  Agriculture, Forestry, Fishing and Hunting      4167.0
#
#    Female_Total  White_Total  Black_Total  Hisp_Total  Asian_Total  ...  \
# 0    38173733.0   42741322.0   11986834.0  14457050.0    5476881.0  ...
# 1      135100.0     113103.0      30723.0    246872.0       6300.0  ...
# 2       54489.0      40388.0       5647.0    111664.0       2236.0  ...
# 3       39664.0      45576.0      21697.0     39627.0       2333.0  ...
# 4         940.0       3212.0        302.0      1439.0         34.0  ...
#
#    Multi_Race_Total  Senior_Managers  Professionals  Technicians  \
# ...

# %%
df2023.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df2023.head()
#
# NameError: name 'df2023' is not defined

# %%
df_total_rmvd = df2023.drop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_total_rmvd = df2023.drop()
#
# NameError: name 'df2023' is not defined
