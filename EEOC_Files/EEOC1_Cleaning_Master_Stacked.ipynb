# %% [markdown]
# Here I will be cleaning the EEOC1_Master_Stacked Data Set

# %%
import pandas as pd
import dtale
import numpy as np

# %%
raw_df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv')
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_62720\1824601255.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: White_Total, 5: Hisp_Total, 6: NHOPIT10, 7: Male_Total, 8: Female_Total, 9: TOTAL1_2, 10: WHM10, 11: WHF10, 12: NHOPIT1, 13: NHOPIT2, 14: NHOPIT3, 15: NHOPIT4, 16: NHOPIT5, 17: NHOPIT6, 18: NHOPIT7, 19: NHOPIT8, 20: NHOPIT9, 21: NHOPIT1_2, 22: TOMRT1, 23: TOMRT2, 24: TOMRT3, 25: TOMRT4, 26: TOMRT5, 27: TOMRT6, 28: TOMRT7, 29: TOMRT8, 30: TOMRT9, 31: TOMRT1_2, 32: nhopiT10, 33: nhopiT1, 34: nhopiT2, 35: nhopiT3, 36: nhopiT4, 37: nhopiT5, 38: nhopiT6, 39: nhopiT7, 40: nhopiT8, 41: nhopiT9, 42: nhopiT1_2, 43: tomrT1, 44: tomrT2, 45: tomrT3, 46: tomrT4, 47: tomrT5, 48: tomrT6, 49: tomrT7, 50: tomrT8, 51: tomrT9, 52: tomrT1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv')

# %%
# Created a copy file so when I mess up, I don't have to keep loading the original dataframe"
df = raw_df.copy()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 561371 entries, 0 to 561370
# Columns: 297 entries, Nation to tomrT1_2
# dtypes: float64(2), int64(3), object(7), str(285)
# memory usage: 1.2+ GB

# %%
df.head()
# Out:
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  tomrT1  tomrT2 tomrT3 tomrT4  \
# 0                                NaN  ...     NaN     NaN    NaN    NaN
# 1                                NaN  ...     NaN     NaN    NaN    NaN
# 2                    Crop Production  ...     NaN     NaN    NaN    NaN
# 3  Animal Production and Aquaculture  ...     NaN     NaN    NaN    NaN
# 4               Forestry and Logging  ...     NaN     NaN    NaN    NaN
#
#   tomrT5 tomrT6 tomrT7 tomrT8 tomrT9 tomrT1_2
# 0    NaN    NaN    NaN    NaN    NaN      NaN
# 1    NaN    NaN    NaN    NaN    NaN      NaN
# 2    NaN    NaN    NaN    NaN    NaN      NaN
# 3    NaN    NaN    NaN    NaN    NaN      NaN
# 4    NaN    NaN    NaN    NaN    NaN      NaN
#
# [5 rows x 297 columns]

# %%
d = dtale.show(df)
d.open_browser()

# %%
#Moving the 'Year' column to the first position on the dataframe
move_columns = df.pop('Year')
df.insert(0, 'Year', move_columns)
df.head()
# Out:
#    Year         Nation Region Division State CBSA County  NAICS2  \
# 0  2014  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  ... tomrT1  tomrT2  \
# 0                                         NaN     NaN  ...    NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN  ...    NaN     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0  ...    NaN     NaN
# 3  Agriculture, Forestry, Fishing and Hunting   112.0  ...    NaN     NaN
# 4  Agriculture, Forestry, Fishing and Hunting   113.0  ...    NaN     NaN
#
#    tomrT3 tomrT4 tomrT5 tomrT6 tomrT7 tomrT8 tomrT9 tomrT1_2
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
#
# [5 rows x 297 columns]

# %%
#quick check of how many rows where in some of the original data frames before being stacked
df2023 = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2023.csv')
df2023.info()
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_62720\903303456.py:2: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2023 = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2023.csv')
# <class 'pandas.DataFrame'>
# RangeIndex: 105613 entries, 0 to 105612
# Columns: 275 entries, Nation to TOMRF1_2
# dtypes: float64(2), int64(2), str(271)
# memory usage: 221.6 MB

# %%
df2014 = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2014.csv')
df2014.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43707 entries, 0 to 43706
# Columns: 275 entries, Nation to TOMRF1_2
# dtypes: float64(2), int64(4), object(2), str(267)
# memory usage: 91.7+ MB
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_62720\1575267954.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2014 = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2014.csv')

# %%
df2019 = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2019.csv')
df2019.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44332 entries, 0 to 44331
# Columns: 275 entries, Nation to TOMRF1_2
# dtypes: float64(2), int64(2), object(5), str(266)
# memory usage: 93.0+ MB
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_62720\2393504089.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: HISPT10, 6: MT10, 7: FT10, 8: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2019 = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2019.csv')

# %%
df.describe()
# Out:
#                 Year         NAICS2         NAICS3  Establishments  \
# count  561371.000000  525862.000000  287405.000000    5.613710e+05
# mean     2019.366909      47.904688     478.318853    1.608241e+02
# std         3.039839      14.540069     139.842270    3.984681e+03
# min      2014.000000      11.000000     111.000000    3.000000e+00
# 25%      2017.000000      33.000000     336.000000    5.000000e+00
# 50%      2020.000000      48.000000     458.000000    1.200000e+01
# 75%      2022.000000      56.000000     561.000000    3.600000e+01
# max      2023.000000      92.000000     928.000000    1.585519e+06
#
#             TOTAL10
# count  5.613710e+05
# mean   1.782720e+04
# std    3.222429e+05
# min    3.000000e+00
# 25%    4.140000e+02
# 50%    1.173000e+03
# 75%    4.252000e+03
# max    7.784510e+07

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.describe(include='all')
# Out:
#                  Year         Nation  Region        Division   State  \
# count   561371.000000         561371  533059          528575  519315
# unique            NaN              1       4               9      51
# top               NaN  United States   South  South Atlantic   Texas
# freq              NaN         561371  210607          103015   34481
# mean      2019.366909            NaN     NaN             NaN     NaN
# std          3.039839            NaN     NaN             NaN     NaN
# min       2014.000000            NaN     NaN             NaN     NaN
# 25%       2017.000000            NaN     NaN             NaN     NaN
# 50%       2020.000000            NaN     NaN             NaN     NaN
# 75%       2022.000000            NaN     NaN             NaN     NaN
# max       2023.000000            NaN     NaN             NaN     NaN
#
#                                          CBSA      County         NAICS2  \
# count                                  472803      301101  525862.000000
# unique                                    932        1835            NaN
# top     New York-Newark-Jersey City, NY-NJ-PA  Washington            NaN
# freq                                    11529        3617            NaN
# mean                                      NaN         NaN      47.904688
# std                                       NaN         NaN      14.540069
# min                                       NaN         NaN      11.000000
# 25%                                       NaN         NaN      33.000000
# 50%                                       NaN         NaN      48.000000
# 75%                                       NaN         NaN      56.000000
# max                                       NaN         NaN      92.000000
#
#           NAICS2_Name         NAICS3  ...  tomrT1  tomrT2  tomrT3  tomrT4  \
# count          525862  287405.000000  ...  341378  341378  341378  341378
# unique             20            NaN  ...     695    3392    1709    2791
# top     Manufacturing            NaN  ...       *       *       *       *
# freq            98526            NaN  ...  326039  250547  285146  258543
# mean              NaN     478.318853  ...     NaN     NaN     NaN     NaN
# std               NaN     139.842270  ...     NaN     NaN     NaN     NaN
# min               NaN     111.000000  ...     NaN     NaN     NaN     NaN
# 25%               NaN     336.000000  ...     NaN     NaN     NaN     NaN
# 50%               NaN     458.000000  ...     NaN     NaN     NaN     NaN
# 75%               NaN     561.000000  ...     NaN     NaN     NaN     NaN
# max               NaN     928.000000  ...     NaN     NaN     NaN     NaN
#
#         tomrT5  tomrT6  tomrT7  tomrT8  tomrT9 tomrT1_2
# count   341378  341378  341378  341378  341378   341378
# unique    2775    1376    2101    2250    3190     2157
# top          *       *       *       *       *        *
# freq    248752  291415  255233  263593  286274   254857
# mean       NaN     NaN     NaN     NaN     NaN      NaN
# std        NaN     NaN     NaN     NaN     NaN      NaN
# min        NaN     NaN     NaN     NaN     NaN      NaN
# 25%        NaN     NaN     NaN     NaN     NaN      NaN
# 50%        NaN     NaN     NaN     NaN     NaN      NaN
# 75%        NaN     NaN     NaN     NaN     NaN      NaN
# max        NaN     NaN     NaN     NaN     NaN      NaN
#
# [11 rows x 297 columns]

# %%
#searching for duplicates
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 561366    False
# 561367    False
# 561368    False
# 561369    False
# 561370    False
# Length: 561371, dtype: bool

# %%
#another check for duplicates
duplicates_only = df[df.duplicated()]
print(duplicates_only)
# Out:
# Empty DataFrame
# Columns: [Year, Nation, Region, Division, State, CBSA, County, NAICS2, NAICS2_Name, NAICS3, NAICS3_Name, Establishments, TOTAL10, White_Total, Black_Total, Hisp_Total, Asian_Total, Amer_Ind_Total, NHOPIT10, Multi_Race_Total, Male_Total, Female_Total, Senior_Managers, Professionals, Technicians, Sales_Workers, Clericals, Craft, Operatives, Labors, Mid_Managers, TOTAL1_2, WHM10, BLKM10, HISPM10, ASIANM10, AIANM10, P_Isld_Total, TOMRM10, WHF10, BLKF10, HISPF10, ASIANF10, AIANF10, NHOPIF10, TOMRF10, WHT1, WHT2, WHT3, WHT4, WHT5, WHT6, WHT7, WHT8, WHT9, WHT1_2, BLKT1, BLKT2, BLKT3, BLKT4, BLKT5, BLKT6, BLKT7, BLKT8, BLKT9, BLKT1_2, HISPT1, HISPT2, HISPT3, HISPT4, HISPT5, HISPT6, HISPT7, HISPT8, HISPT9, HISPT1_2, ASIANT1, ASIANT2, ASIANT3, ASIANT4, ASIANT5, ASIANT6, ASIANT7, ASIANT8, ASIANT9, ASIANT1_2, AIANT1, AIANT2, AIANT3, AIANT4, AIANT5, AIANT6, AIANT7, AIANT8, AIANT9, AIANT1_2, NHOPIT1, NHOPIT2, NHOPIT3, NHOPIT4, ...]
# Index: []
#
# [0 rows x 297 columns]

# %%
df.isnull()
# Out:
#          Year  Nation  Region  Division  State   CBSA  County  NAICS2  \
# 0       False   False    True      True   True   True    True    True
# 1       False   False    True      True   True   True    True   False
# 2       False   False    True      True   True   True    True   False
# 3       False   False    True      True   True   True    True   False
# 4       False   False    True      True   True   True    True   False
# ...       ...     ...     ...       ...    ...    ...     ...     ...
# 561366  False   False   False     False  False  False   False   False
# 561367  False   False   False     False  False  False   False   False
# 561368  False   False   False     False  False  False   False   False
# 561369  False   False   False     False  False  False   False   False
# 561370  False   False   False     False  False  False   False   False
#
#         NAICS2_Name  NAICS3  ...  tomrT1  tomrT2  tomrT3  tomrT4  tomrT5  \
# 0              True    True  ...    True    True    True    True    True
# 1             False    True  ...    True    True    True    True    True
# 2             False   False  ...    True    True    True    True    True
# 3             False   False  ...    True    True    True    True    True
# 4             False   False  ...    True    True    True    True    True
# ...             ...     ...  ...     ...     ...     ...     ...     ...
# 561366        False   False  ...   False   False   False   False   False
# 561367        False   False  ...   False   False   False   False   False
# 561368        False    True  ...   False   False   False   False   False
# 561369        False    True  ...   False   False   False   False   False
# 561370        False   False  ...   False   False   False   False   False
#
#         tomrT6  tomrT7  tomrT8  tomrT9  tomrT1_2
# 0         True    True    True    True      True
# 1         True    True    True    True      True
# 2         True    True    True    True      True
# 3         True    True    True    True      True
# 4         True    True    True    True      True
# ...        ...     ...     ...     ...       ...
# 561366   False   False   False   False     False
# 561367   False   False   False   False     False
# 561368   False   False   False   False     False
# 561369   False   False   False   False     False
# 561370   False   False   False   False     False
#
# [561371 rows x 297 columns]

# %%
df.head()
# Out:
#    Year         Nation Region Division State CBSA County  NAICS2  \
# 0  2014  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  ... tomrT1  tomrT2  \
# 0                                         NaN     NaN  ...    NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN  ...    NaN     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0  ...    NaN     NaN
# 3  Agriculture, Forestry, Fishing and Hunting   112.0  ...    NaN     NaN
# 4  Agriculture, Forestry, Fishing and Hunting   113.0  ...    NaN     NaN
#
#    tomrT3 tomrT4 tomrT5 tomrT6 tomrT7 tomrT8 tomrT9 tomrT1_2
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN
#
# [5 rows x 297 columns]

# %%
#Replaceing the '*' values with NaN in the columns I want to make numeric. 
df.replace('*', np.nan, inplace=True)
d = dtale.show(df)
d.open_browser()

# %%
df.iloc[:, 11]
# Out:
# 0         260632
# 1           1268
# 2            587
# 3            349
# 4             30
#            ...
# 561366       100
# 561367        24
# 561368        62
# 561369        24
# 561370         7
# Name: Establishments, Length: 561371, dtype: int64

# %%
#I need to change all of my columns after 'Establishments' to numeric
#df.iloc[:, 11:] = pd.to_numeric(df.iloc[:, 11:], errors= 'coerce')
#df.dtypes
#df.info()

# %%
#The above cell didn't work. After researching, I'm trying this code instead
df.iloc[:, 11:] = df.iloc[:, 11:].apply(pd.to_numeric, errors='coerce')
df.dtypes
df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:2144, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2143 try:
# -> 2144     self.obj._mgr.column_setitem(
#    2145         loc, plane_indexer, value, inplace_only=True
#    2146     )
#    2147 except (ValueError, TypeError, LossySetitemError) as exc:
#    2148     # If we're setting an entire column and we can't do it inplace,
#    2149     #  then we can use value's dtype (or inferred dtype)
#    2150     #  instead of object
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:1518, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1517 if inplace_only:
# -> 1518     col_mgr.setitem_inplace(idx, value)
#    1519 else:
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:2226, in SingleBlockManager.setitem_inplace(self, indexer, value)
#    2224     value = value[0, ...]
# -> 2226 arr[indexer] = value
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arrays\string_.py:863, in StringArray.__setitem__(self, key, value)
#     861     raise ValueError("Cannot modify read-only array")
# --> 863 value = self._maybe_convert_setitem_value(value)
#     865 key = check_array_indexer(self, key)
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arrays\string_.py:853, in StringArray._maybe_convert_setitem_value(self, value)
#     852     if len(value) and not lib.is_string_array(value, skipna=True):
# --> 853         raise TypeError(
#     854             "Invalid value for dtype 'str'. Value should be a "
#     855             "string or missing value (or array of those)."
#     856         )
#     857 return value
#
# TypeError: Invalid value for dtype 'str'. Value should be a string or missing value (or array of those).
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #The above cell didn't work. After researching, I'm trying this code instead
# ----> 2 df.iloc[:, 11:] = df.iloc[:, 11:].apply(pd.to_numeric, errors='coerce')
#       3 df.dtypes
#       4 df.info()
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
#    1955     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1988, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1986 if is_list_like_indexer(value) and getattr(value, "ndim", 1) > 0:
#    1987     if isinstance(value, ABCDataFrame):
# -> 1988         self._setitem_with_indexer_frame_value(indexer, value, name)
#    1990     elif np.ndim(value) == 2:
#    1991         # TODO: avoid np.ndim call in case it isn't an ndarray, since
#    1992         #  that will construct an ndarray, which will be wasteful
#    1993         self._setitem_with_indexer_2d_value(indexer, value)
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:2084, in _iLocIndexer._setitem_with_indexer_frame_value(self, indexer, value, name)
#    2082     for i, loc in enumerate(ilocs):
#    2083         val = value.iloc[:, i]
# -> 2084         self._setitem_single_column(loc, val, pi)
#    2086 elif not unique_cols and value.columns.equals(self.obj.columns):
#    2087     # We assume we are already aligned, see
#    2088     # test_iloc_setitem_frame_duplicate_columns_multiple_blocks
#    2089     for loc in ilocs:
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:2163, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2151         dtype = self.obj.dtypes.iloc[loc]
#    2152         if dtype not in (np.void, object) and not self.obj.empty:
#    2153             # - Exclude np.void, as that is a special case for expansion.
#    2154             #   We want to raise for
#    (...)   2161             # - Exclude empty initial object with enlargement,
#    2162             #   as then there's nothing to be inconsistent with.
# -> 2163             raise TypeError(
#    2164                 f"Invalid value '{value}' for dtype '{dtype}'"
#    2165             ) from exc
#    2166         self.obj.isetitem(loc, value)
#    2167 else:
#    2168     # set value into the column (first attempting to operate inplace, then
#    2169     #  falling back to casting if necessary)
#
# TypeError: Invalid value '0         7408929.0
# 1           15875.0
# 2            3682.0
# 3            9389.0
# 4             132.0
#             ...
# 561366         51.0
# 561367         36.0
# 561368         34.0
# 561369          4.0
# 561370          NaN
# Name: Black_Total, Length: 561371, dtype: float64' for dtype 'str'

# %%
# 1. Grab the first 11 columns (leave them exactly as they are)
left_side = df.iloc[:, :11]

# 2. Grab column 11 onwards and convert them to numbers
right_side = df.iloc[:, 11:].apply(pd.to_numeric, errors='coerce')

# 3. Glue them back together side-by-side (axis=1) into a new dataframe
df = pd.concat([left_side, right_side], axis=1)

df.dtypes
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 561371 entries, 0 to 561370
# Columns: 297 entries, Year to tomrT1_2
# dtypes: float64(286), int64(3), str(8)
# memory usage: 1.2 GB

# %%
d = dtale.show(df)
d.open_browser()
df.head()
# Out:
#    Year         Nation Region Division State CBSA County  NAICS2  \
# 0  2014  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  2014  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  ... tomrT1  tomrT2  \
# 0                                         NaN     NaN  ...    NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN  ...    NaN     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0  ...    NaN     NaN
# 3  Agriculture, Forestry, Fishing and Hunting   112.0  ...    NaN     NaN
# 4  Agriculture, Forestry, Fishing and Hunting   113.0  ...    NaN     NaN
#
#    tomrT3  tomrT4  tomrT5  tomrT6  tomrT7  tomrT8  tomrT9  tomrT1_2
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
#
# [5 rows x 297 columns]

# %%
#Change all floats to int
