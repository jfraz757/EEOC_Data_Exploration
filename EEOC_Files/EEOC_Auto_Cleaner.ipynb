# %% [markdown]
# After Successfully Cleaning the EEOC_1 2023 Dataset. I am creating a function to auto clean the rest using the same scripts from my first attempt.

# %%
import pandas as pd
import dtale
import numpy as np
import os
import re

# %%
def EEOC_Auto_Clean(file_path):

    df = pd.read_csv(file_path)
    
    #Renaming Total_Race Variables
    df.rename({
        'WHT10' : "White_Total",
        'BLKT10' : 'Black_Total',
        'HISPT10' : 'Hisp_Total',
        'ASIANT10' : 'Asian_Total',
        'AIANT10' : 'Amer_Ind_Total', 
        'NHOPIM10' : 'P_Isld_Total', 
        'tomrT10' : 'Multi_Race_Total'

    }, axis=1, inplace=True)

    #Renaming Total_Sex Variables
    df.rename({
    'MT10' : 'Male_Total',
    'FT10': 'Female_Total'
    }, axis=1, inplace=True)


    #Renaming Job_Levels
    df.rename({
        'TOTAL1': 'Senior_Managers', 
        'TOTAL2': 'Professionals',
        'TOTAL3': "Technicians",
        'TOTAL4': 'Sales_Workers',
        'TOTAL5': 'Clericals',
        'TOTAL6': 'Craft',
        'TOTAL7': 'Operatives',
        'TOTAL8': 'Labors',
        'TOTAL9': 'Mid_Managers'
    }, axis= 1, inplace=True)

    #Add a Year Column that will all of the values with the year from the filepath name
    def extract_year_from_file_path(file_path):
        file_name = os.path.basename(file_path)
        year_pattern = r'(19|20)\d{2}'
        match = re.search(year_pattern, file_name)
        if match:
            return match.group()

        else:
            return None
        
    year_var = extract_year_from_file_path(file_path)

        
    df['Year'] = year_var

    #New Dataframe with Agg Columns Removed

    df_cln = df[['Year', 'State', 'County', 'NAICS2_Name', 'Male_Total', 'Female_Total', 'White_Total','Black_Total', 'Hisp_Total',
                'Asian_Total', 'Amer_Ind_Total', 'P_Isld_Total', 'Multi_Race_Total',
                'Senior_Managers', 'Professionals', 'Technicians', 'Sales_Workers', 'Clericals', 'Craft', 'Operatives', 'Labors', 'Mid_Managers'
    ]]
    
    #make sure all values in Male_Total Column are a number
    df_cln = df_cln.replace(['*', ''], np.nan)

    #Change Total Columns to Int
    df_cln = df_cln.astype({'Male_Total': 'Int64', 'Female_Total': 'Int64', 'White_Total': 'Int64','Black_Total': 'Int64', 'Hisp_Total': 'Int64', 
                   'Asian_Total': 'Int64', 'Amer_Ind_Total': 'Int64', 'P_Isld_Total': 'Int64', 'Multi_Race_Total': 'Int64', 
                   'Senior_Managers': 'Int64', 'Professionals': 'Int64', 'Technicians': 'Int64', 'Sales_Workers': 'Int64', 
                   'Clericals': 'Int64', 'Craft': 'Int64', 'Operatives': 'Int64', 'Labors': 'Int64', 'Mid_Managers': 'Int64'

    })

    return df_cln

my_file = r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2022.csv'

final_clean_df = EEOC_Auto_Clean(my_file)

print(final_clean_df.head())
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_23420\2761304546.py:3: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#    Year State County                                 NAICS2_Name  Male_Total  \
# 0  2022   NaN    NaN                                         NaN    38794034
# 1  2022   NaN    NaN  Agriculture, Forestry, Fishing and Hunting      260752
# 2  2022   NaN    NaN  Agriculture, Forestry, Fishing and Hunting      103425
# 3  2022   NaN    NaN  Agriculture, Forestry, Fishing and Hunting       69564
# 4  2022   NaN    NaN  Agriculture, Forestry, Fishing and Hunting        4464
#
#    Female_Total  White_Total  Black_Total  Hisp_Total  Asian_Total  ...  \
# 0      37048191     42409164     11647147    13499428      5248156  ...
# 1        133275       118918        28500      231524         7115  ...
# 2         53310        40065         5500      106012         2250  ...
# 3         42502        50303        19687       36080         3100  ...
# 4          1202         3521          227        1745           34  ...
#
#    Multi_Race_Total  Senior_Managers  Professionals  Technicians  \
# 0           2110502          1168977       16496984      4049643
# 1              4372             5548          19244        16601
# 2              1623             2319           5805         4827
# 3              1468             1710           8566         8962
# 4                67              106            716          141
#
#    Sales_Workers  Clericals    Craft  Operatives   Labors  Mid_Managers
# 0        9471929    8166479  3731758     7075438  6030203      11728388
# 1          10343      17751    15264       54415   214816          9178
# 2           7264       7236     4220       18682    89240          4753
# 3            850       5107     5807       20785    47783          1156
# 4             71        356      321        1258     2145            14
#
# [5 rows x 22 columns]

# %%
# Save the dataframe to a new CSV file
final_clean_df.to_csv(r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data\EEOC1_2022_Cleaned.csv', index=False)

# %%
final_clean_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103475 entries, 0 to 103474
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Year              103475 non-null  str
#  1   State             98232 non-null   str
#  2   County            61031 non-null   str
#  3   NAICS2_Name       99441 non-null   str
#  4   Male_Total        100262 non-null  Int64
#  5   Female_Total      100262 non-null  Int64
#  6   White_Total       100520 non-null  Int64
#  7   Black_Total       76124 non-null   Int64
#  8   Hisp_Total        80311 non-null   Int64
#  9   Asian_Total       50191 non-null   Int64
#  10  Amer_Ind_Total    34000 non-null   Int64
#  11  P_Isld_Total      13913 non-null   Int64
#  12  Multi_Race_Total  66303 non-null   Int64
#  13  Senior_Managers   33573 non-null   Int64
#  14  Professionals     74711 non-null   Int64
#  15  Technicians       59460 non-null   Int64
#  16  Sales_Workers     76117 non-null   Int64
#  17  Clericals         85184 non-null   Int64
#  18  Craft             62843 non-null   Int64
#  19  Operatives        65571 non-null   Int64
#  20  Labors            63509 non-null   Int64
#  21  Mid_Managers      45678 non-null   Int64
# dtypes: Int64(18), str(4)
# memory usage: 19.1 MB
