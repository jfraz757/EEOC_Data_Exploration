# %% [markdown]
# This new version of the EEOC_Auto_Cleaner will now change the final file name and save it to the correct folder as well.

# %%
import pandas as pd
import numpy as np
import os
import re

def EEOC_Auto_Clean(file_path, output_dir=r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data'):

    df = pd.read_csv(file_path)
    
    # Renaming Total_Race Variables
    df.rename({
        'WHT10' : "White_Total",
        'BLKT10' : 'Black_Total',
        'HISPT10' : 'Hisp_Total',
        'ASIANT10' : 'Asian_Total',
        'AIANT10' : 'Amer_Ind_Total', 
        'NHOPIM10' : 'P_Isld_Total', 
        'tomrT10' : 'Multi_Race_Total'
    }, axis=1, inplace=True)

    # Renaming Total_Sex Variables
    df.rename({
        'MT10' : 'Male_Total',
        'FT10': 'Female_Total'
    }, axis=1, inplace=True)

    # Renaming Job_Levels
    df.rename({
        'TOTAL1': 'Senior_Managers', 
        'TOTAL2': 'Professionals',
        'TOTAL3': "Technicians",
        'TOTAL4': 'Sales_Workers',
        'TOTAL5': 'Clericals',
        'TOTAL6': 'Craft',
        'TOTAL7': 'Operatives',
        'TOTAL8': 'Labors',
        'TOTAL9': 'Mid_Managers'
    }, axis= 1, inplace=True)

    # Add a Year Column
    def extract_year_from_file_path(file_path):
        file_name = os.path.basename(file_path)
        year_pattern = r'(19|20)\d{2}'
        match = re.search(year_pattern, file_name)
        if match:
            return match.group()
        else:
            return "Unknown_Year"
        
    year_var = extract_year_from_file_path(file_path)
    df['Year'] = year_var

    # New Dataframe with Agg Columns Removed
    df_cln = df[['Year', 'State', 'County', 'NAICS2_Name', 'Male_Total', 'Female_Total', 'White_Total','Black_Total', 'Hisp_Total',
                'Asian_Total', 'Amer_Ind_Total', 'P_Isld_Total', 'Multi_Race_Total',
                'Senior_Managers', 'Professionals', 'Technicians', 'Sales_Workers', 'Clericals', 'Craft', 'Operatives', 'Labors', 'Mid_Managers'
    ]].copy() # Added .copy() to prevent SettingWithCopyWarning
    
    # --- ROBUST TYPE CASTING ---
    # List of all columns that need to be integers
    int_columns = [
        'Male_Total', 'Female_Total', 'White_Total', 'Black_Total', 'Hisp_Total',
        'Asian_Total', 'Amer_Ind_Total', 'P_Isld_Total', 'Multi_Race_Total',
        'Senior_Managers', 'Professionals', 'Technicians', 'Sales_Workers',
        'Clericals', 'Craft', 'Operatives', 'Labors', 'Mid_Managers'
    ]

    for col in int_columns:
        # 1. Convert to string and remove commas (e.g. "1,000" -> "1000")
        df_cln[col] = df_cln[col].astype(str).str.replace(',', '', regex=False)
        # 2. Coerce to numeric (turns '*', '', and text into np.nan)
        df_cln[col] = pd.to_numeric(df_cln[col], errors='coerce')
        # 3. Safely cast to nullable Int64
        df_cln[col] = df_cln[col].astype('Int64')

    # --- AUTOMATED SAVING PROCESS ---
    os.makedirs(output_dir, exist_ok=True)
    new_file_name = f"EEOC1_{year_var}_Cleaned.csv"
    full_export_path = os.path.join(output_dir, new_file_name)
    
    df_cln.to_csv(full_export_path, index=False)
    print(f"Successfully cleaned and saved: {full_export_path}")

    return df_cln

# Execution
my_file = r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2017ls.csv'

final_clean_df = EEOC_Auto_Clean(my_file)
print(final_clean_df.head())
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_22860\1177898001.py:8: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: MT10, 6: FT10, 7: TOTAL1_2, 8: WHM10, 9: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 89
#      86 # Execution
#      87 my_file = r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2017.csv'
# ---> 89 final_clean_df = EEOC_Auto_Clean(my_file)
#      90 print(final_clean_df.head())
#
# Cell In[6], line 54, in EEOC_Auto_Clean(file_path, output_dir)
#      51 df['Year'] = year_var
#      53 # New Dataframe with Agg Columns Removed
# ---> 54 df_cln = df[['Year', 'State', 'County', 'NAICS2_Name', 'Male_Total', 'Female_Total', 'White_Total','Black_Total', 'Hisp_Total',
#      55             'Asian_Total', 'Amer_Ind_Total', 'P_Isld_Total', 'Multi_Race_Total',
#      56             'Senior_Managers', 'Professionals', 'Technicians', 'Sales_Workers', 'Clericals', 'Craft', 'Operatives', 'Labors', 'Mid_Managers'
#      57 ]].copy() # Added .copy() to prevent SettingWithCopyWarning
#      59 # --- ROBUST TYPE CASTING ---
#      60 # List of all columns that need to be integers
#      61 int_columns = [
#      62     'Male_Total', 'Female_Total', 'White_Total', 'Black_Total', 'Hisp_Total',
#      63     'Asian_Total', 'Amer_Ind_Total', 'P_Isld_Total', 'Multi_Race_Total',
#      64     'Senior_Managers', 'Professionals', 'Technicians', 'Sales_Workers',
#      65     'Clericals', 'Craft', 'Operatives', 'Labors', 'Mid_Managers'
#      66 ]
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\jfraz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Multi_Race_Total'] not in index"

# %%
#Same code but later data changed the way some varibales were named. Had to tweak the TOMRT10 Variable to all caps
import pandas as pd
import numpy as np
import os
import re

def EEOC_Auto_Clean(file_path, output_dir=r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data'):

    df = pd.read_csv(file_path)
    
    # Renaming Total_Race Variables
    df.rename({
        'WHT10' : "White_Total",
        'BLKT10' : 'Black_Total',
        'HISPT10' : 'Hisp_Total',
        'ASIANT10' : 'Asian_Total',
        'AIANT10' : 'Amer_Ind_Total', 
        'NHOPIM10' : 'P_Isld_Total', 
        'TOMRT10' : 'Multi_Race_Total'
    }, axis=1, inplace=True)

    # Renaming Total_Sex Variables
    df.rename({
        'MT10' : 'Male_Total',
        'FT10': 'Female_Total'
    }, axis=1, inplace=True)

    # Renaming Job_Levels
    df.rename({
        'TOTAL1': 'Senior_Managers', 
        'TOTAL2': 'Professionals',
        'TOTAL3': "Technicians",
        'TOTAL4': 'Sales_Workers',
        'TOTAL5': 'Clericals',
        'TOTAL6': 'Craft',
        'TOTAL7': 'Operatives',
        'TOTAL8': 'Labors',
        'TOTAL9': 'Mid_Managers'
    }, axis= 1, inplace=True)

    # Add a Year Column
    def extract_year_from_file_path(file_path):
        file_name = os.path.basename(file_path)
        year_pattern = r'(19|20)\d{2}'
        match = re.search(year_pattern, file_name)
        if match:
            return match.group()
        else:
            return "Unknown_Year"
        
    year_var = extract_year_from_file_path(file_path)
    df['Year'] = year_var

    # New Dataframe with Agg Columns Removed
    df_cln = df[['Year', 'State', 'County', 'NAICS2_Name', 'Male_Total', 'Female_Total', 'White_Total','Black_Total', 'Hisp_Total',
                'Asian_Total', 'Amer_Ind_Total', 'P_Isld_Total', 'Multi_Race_Total',
                'Senior_Managers', 'Professionals', 'Technicians', 'Sales_Workers', 'Clericals', 'Craft', 'Operatives', 'Labors', 'Mid_Managers'
    ]].copy() # Added .copy() to prevent SettingWithCopyWarning
    
    # --- ROBUST TYPE CASTING ---
    # List of all columns that need to be integers
    int_columns = [
        'Male_Total', 'Female_Total', 'White_Total', 'Black_Total', 'Hisp_Total',
        'Asian_Total', 'Amer_Ind_Total', 'P_Isld_Total', 'Multi_Race_Total',
        'Senior_Managers', 'Professionals', 'Technicians', 'Sales_Workers',
        'Clericals', 'Craft', 'Operatives', 'Labors', 'Mid_Managers'
    ]

    for col in int_columns:
        # 1. Convert to string and remove commas (e.g. "1,000" -> "1000")
        df_cln[col] = df_cln[col].astype(str).str.replace(',', '', regex=False)
        # 2. Coerce to numeric (turns '*', '', and text into np.nan)
        df_cln[col] = pd.to_numeric(df_cln[col], errors='coerce')
        # 3. Safely cast to nullable Int64
        df_cln[col] = df_cln[col].astype('Int64')

    # --- AUTOMATED SAVING PROCESS ---
    os.makedirs(output_dir, exist_ok=True)
    new_file_name = f"EEOC1_{year_var}_Cleaned.csv"
    full_export_path = os.path.join(output_dir, new_file_name)
    
    df_cln.to_csv(full_export_path, index=False)
    print(f"Successfully cleaned and saved: {full_export_path}")

    return df_cln

# Execution
my_file = r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2014.csv'

final_clean_df = EEOC_Auto_Clean(my_file)
print(final_clean_df.head())
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_22860\492805138.py:9: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Successfully cleaned and saved: C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data\EEOC1_2014_Cleaned.csv
#    Year State County                                 NAICS2_Name  Male_Total  \
# 0  2014   NaN    NaN                                         NaN    26728926
# 1  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting      187857
# 2  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting       90891
# 3  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting       45938
# 4  2014   NaN    NaN  Agriculture, Forestry, Fishing and Hunting        2497
#
#    Female_Total  White_Total  Black_Total  Hisp_Total  Asian_Total  ...  \
# 0      24422889     32348361      7408929     7066158      3068313  ...
# 1         90345        86127        15875      165020         7013  ...
# 2         43864        30544         3682       95595         3067  ...
# 3         22085        32517         9389       22823         2142  ...
# 4           734         2650          132         305           54  ...
#
#    Multi_Race_Total  Senior_Managers  Professionals  Technicians  \
# 0            761483           833367       10534689      2870353
# 1              1651             4044          13505         5874
# 2               679             1854           7206         2037
# 3               382             1055           2347         2230
# 4                26               84            786          116
#
#    Sales_Workers  Clericals    Craft  Operatives   Labors  Mid_Managers
# 0        5681336    6533111  2950753     5337312  3777568       7867285
# 1           7045      12631    12195       38015   159938          5716
# 2           4055       5378     4361       13319    85464          2455
# 3            724       3050     4449       12764    33742          1557
# 4             45        275      499         624      348            80
#
# [5 rows x 22 columns]
