# %% [markdown]
# I am creating a function to stack all of my EEOC1 2023-2014 Dataframes into one large table.

# %%
import pandas as pd
from pathlib import Path
import os

# %%
def stack_csv(file_folder):
    folder_path = Path(file_folder)

    df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]

    final_df = pd.concat(df_list, ignore_index=True)
    
    EEOC1_Master_Stacked = final_df

    EEOC1_Master_Stacked.to_csv(r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv', index=False)

    return EEOC1_Master_Stacked

my_folder = r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data'

final_stack = stack_csv(my_folder)
print(final_stack.head())
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: Male_Total, 6: Female_Total, 7: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: HISPT10, 6: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: Male_Total, 6: Female_Total, 7: TOTAL1_2, 8: WHM10, 9: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: HISPT10, 6: Male_Total, 7: Female_Total, 8: TOTAL1_2, 9: WHM10, 10: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: HISPT10, 6: Male_Total, 7: Female_Total, 8: TOTAL1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: HISPT10, 6: Clericals, 7: TOTAL1_2, 8: WHM10, 9: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\4284730039.py:4: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(file) for file in folder_path.glob('*.csv')]
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  tomrT1  tomrT2 tomrT3 tomrT4  \
# 0                                NaN  ...     NaN     NaN    NaN    NaN
# 1                                NaN  ...     NaN     NaN    NaN    NaN
# 2                    Crop Production  ...     NaN     NaN    NaN    NaN
# 3  Animal Production and Aquaculture  ...     NaN     NaN    NaN    NaN
# 4               Forestry and Logging  ...     NaN     NaN    NaN    NaN
#
#   tomrT5 tomrT6 tomrT7 tomrT8 tomrT9 tomrT1_2
# 0    NaN    NaN    NaN    NaN    NaN      NaN
# 1    NaN    NaN    NaN    NaN    NaN      NaN
# 2    NaN    NaN    NaN    NaN    NaN      NaN
# 3    NaN    NaN    NaN    NaN    NaN      NaN
# 4    NaN    NaN    NaN    NaN    NaN      NaN
#
# [5 rows x 298 columns]

# %%
df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv')
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_119076\2880195732.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: HISPT10, 6: NHOPIT10, 7: TOMRT10, 8: Male_Total, 9: Female_Total, 10: TOTAL1_2, 11: WHM10, 12: WHF10, 13: NHOPIT1, 14: NHOPIT2, 15: NHOPIT3, 16: NHOPIT4, 17: NHOPIT5, 18: NHOPIT6, 19: NHOPIT7, 20: NHOPIT8, 21: NHOPIT9, 22: NHOPIT1_2, 23: TOMRT1, 24: TOMRT2, 25: TOMRT3, 26: TOMRT4, 27: TOMRT5, 28: TOMRT6, 29: TOMRT7, 30: TOMRT8, 31: TOMRT9, 32: TOMRT1_2, 33: nhopiT10, 34: tomrT10, 35: nhopiT1, 36: nhopiT2, 37: nhopiT3, 38: nhopiT4, 39: nhopiT5, 40: nhopiT6, 41: nhopiT7, 42: nhopiT8, 43: nhopiT9, 44: nhopiT1_2, 45: tomrT1, 46: tomrT2, 47: tomrT3, 48: tomrT4, 49: tomrT5, 50: tomrT6, 51: tomrT7, 52: tomrT8, 53: tomrT9, 54: tomrT1_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv')

# %%
df.head()
# Out:
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_Name  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_Name  ...  tomrT1  tomrT2 tomrT3 tomrT4  \
# 0                                NaN  ...     NaN     NaN    NaN    NaN
# 1                                NaN  ...     NaN     NaN    NaN    NaN
# 2                    Crop Production  ...     NaN     NaN    NaN    NaN
# 3  Animal Production and Aquaculture  ...     NaN     NaN    NaN    NaN
# 4               Forestry and Logging  ...     NaN     NaN    NaN    NaN
#
#   tomrT5 tomrT6 tomrT7 tomrT8 tomrT9 tomrT1_2
# 0    NaN    NaN    NaN    NaN    NaN      NaN
# 1    NaN    NaN    NaN    NaN    NaN      NaN
# 2    NaN    NaN    NaN    NaN    NaN      NaN
# 3    NaN    NaN    NaN    NaN    NaN      NaN
# 4    NaN    NaN    NaN    NaN    NaN      NaN
#
# [5 rows x 298 columns]

# %%
df['Year'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
df['Year'].value_counts()
# Out:
# Year
# 2023    105613
# 2022    103475
# 2021     45143
# 2016     44460
# 2019     44332
# 2015     44179
# 2018     43919
# 2017     43728
# 2014     43707
# 2020     42815
# Name: count, dtype: int64

# %%
#I finally cought the issue. the two or more race and Pacific islander variables were formatted differntly depending on the table year. 
#by making all variable names capitalized, It fixed the problem. 
import pandas as pd
from pathlib import Path

def stack_csv(file_folder):
    folder_path = Path(file_folder)
    df_list = []

    for file in folder_path.glob('*.csv'):
        # Read file and prevent mixed data type warnings
        temp_df = pd.read_csv(file, low_memory=False)
        
        # Remove hidden spaces and force uppercase for perfect column alignment
        temp_df.columns = temp_df.columns.str.strip()
        temp_df.columns = temp_df.columns.str.upper()
        
        df_list.append(temp_df)

    # Stack all cleaned dataframes together
    final_df = pd.concat(df_list, ignore_index=True)
    
    # Define the exact output path on your computer
    output_path = r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC1_Master_Stacked.csv'
    
    # Save the master file
    final_df.to_csv(output_path, index=False)

    return final_df

# Run the function
my_folder = r'C:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_Cleaned_Data'
final_stack = stack_csv(my_folder)

# Verify the results
print(final_stack.head())
# Out:
#           NATION REGION DIVISION STATE CBSA COUNTY  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
#
#                                   NAICS2_NAME  NAICS3  \
# 0                                         NaN     NaN
# 1  Agriculture, Forestry, Fishing and Hunting     NaN
# 2  Agriculture, Forestry, Fishing and Hunting   111.0
# 3  Agriculture, Forestry, Fishing and Hunting   112.0
# 4  Agriculture, Forestry, Fishing and Hunting   113.0
#
#                          NAICS3_NAME  ...  NHOPIM1_2  TOMRM1_2   WHF1_2  \
# 0                                NaN  ...       7118     25224  1406699
# 1                                NaN  ...         24        50     3327
# 2                    Crop Production  ...          *        25        *
# 3  Animal Production and Aquaculture  ...          *         7        *
# 4               Forestry and Logging  ...          *         *        *
#
#   BLKF1_2 HISPF1_2 ASIANF1_2 AIANF1_2 NHOPIF1_2 TOMRF1_2  YEAR
# 0  170431   135342    110903     6999      5657    20823  2014
# 1     175      743       142       27        13       37  2014
# 2       *        *        98        *         *       19  2014
# 3      92      104        17        9         *        7  2014
# 4       5        *         *        *         *        *  2014
#
# [5 rows x 276 columns]
