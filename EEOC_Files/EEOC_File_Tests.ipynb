# %% [markdown]
# Created this notebook to play around with different EEOC CSV to look for formatting issues that aren't consistant across files

# %%
import pandas as pd
import numpy as np
import os
import re
import dtale

# %%
df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2018.csv')
# Out:
# C:\Users\jfraz\AppData\Local\Temp\ipykernel_29504\3749598494.py:1: DtypeWarning: Columns (0: Region, 1: Division, 2: State, 3: County, 4: WHT10, 5: HISPT10, 6: MT10, 7: FT10, 8: TOTAL1_2, 9: WHM10, 10: WHF10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'c:\Users\jfraz\Code_You_Data_Analytics_Pathway\EEOC_Project\EEOC_Data\EEOC_1_Data\EEOC1_2018.csv')

# %%
d =dtale.show(df)
d.open_browser()
